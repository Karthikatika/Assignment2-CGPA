# %%
# 1. Karthika's marks
Karthika = { "name":"Karthika",
         "assignment" : [80,95,89,90],
         "test" : [75, 75],
         "lab" : [78.20, 77.20]
       }
         
# 2. Sabana's marks
Sabana = { "name":"Sabana",
          "assignment" : [82,86,94,80,97],
          "test" : [80,80],
          "lab" : [67.90, 78.72]
        }
  
# 3. Pavi's marks
Pavi = { "name" : "Pavi",
          "assignment" : [77,82,83,99,89],
          "test" : [78,77],
          "lab" : [80,80]
        }
          
# 4. Manisha's marks
Manisha = { "name" : "Manisha",
         "assignment" : [77,55,77,71,89],
         "test" : [40,50],
         "lab" : [69,44.56]
       }
         
# 5. bharani's marks
Bharani = { "name" : "Bharani",
        "assignment" : [79,89,90,96,80],
        "test" : [65,56],
        "lab" : [50,40.6]
      }

def get_average(marks):
    total_sum = sum(marks)
    total_sum = float(total_sum)
    return total_sum / len(marks)
  
# Function calculates total average
def calculate_total_average(students):
    assignment = get_average(students["assignment"])
    test = get_average(students["test"])
    lab = get_average(students["lab"])
  
    return (0.1 * assignment +
            0.7 * test + 0.2 * lab)
  

def assign_letter_grade(score):
    if score >= 90: return "A"
  
    elif score >= 80: return "B"
    elif score >= 70: return "C"
    elif score >= 60: return "D"
    else : return "E"

def class_average_is(student_list):
    result_list = []
  
    for student in student_list:
        stud_avg = calculate_total_average(student)
        result_list.append(stud_avg)
        return get_average(result_list)

students = [Karthika,Sabana,Pavi,Manisha,Bharani]
  

for i in students :
    print(i["name"])
    print("***")
    print("Average marks of %s is : %s " %(i["name"],
                         calculate_total_average(i)))
                           
    print("Letter Grade of %s is : %s" %(i["name"],
    assign_letter_grade(calculate_total_average(i))))
      
    print()
  

class_av = class_average_is(students)
  
print( "Class Average is %s" %(class_av))
print("Letter Grade of the class is %s " 
        %(assign_letter_grade(class_av)))
# Out:
# Karthika
# ***
# Average marks of Karthika is : 76.89
# Letter Grade of Karthika is : C
#
# Sabana
# ***
# Average marks of Sabana is : 79.44200000000001
# Letter Grade of Sabana is : C
#
# Pavi
# ***
# Average marks of Pavi is : 78.85
# Letter Grade of Pavi is : C
#
# Manisha
# ***
# Average marks of Manisha is : 50.236
# Letter Grade of Manisha is : E
#
# Bharani
# ***
# Average marks of Bharani is : 60.089999999999996
# Letter Grade of Bharani is : D
#
# Class Average is 76.89
# Letter Grade of the class is C
